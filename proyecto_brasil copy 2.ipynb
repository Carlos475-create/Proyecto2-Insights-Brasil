# %%
import pandas as pd

# %%
datos_2013 = pd.read_csv("/Users/Charlie/Desktop/hackio/Proyecto2-EDA-Ingresos-Publicos-Brasil/datos/datos-2013.csv", encoding='ISO-8859-1', on_bad_lines='skip', sep=';')
datos_2013
# Out:
#       CÓDIGO ÓRGÃO SUPERIOR       NOME ÓRGÃO SUPERIOR  CÓDIGO ÓRGÃO  \
# 0                     63000  Advocacia-Geral da União         63000
# 1                     63000  Advocacia-Geral da União         63000
# 2                     63000  Advocacia-Geral da União         63000
# 3                     63000  Advocacia-Geral da União         63000
# 4                     63000  Advocacia-Geral da União         63000
# ...                     ...                       ...           ...
# 4493                  20000  Presidência da República         20101
# 4494                  20000  Presidência da República         64000
# 4495                  20000  Presidência da República         20101
# 4496                  20000  Presidência da República         20116
# 4497                  20000  Presidência da República         24208
#
#                                              NOME ÓRGÃO  \
# 0     Advocacia-Geral da União - Unidades com víncul...
# ...

# %%
datos_2014 = pd.read_csv("/Users/Charlie/Desktop/hackio/Proyecto2-EDA-Ingresos-Publicos-Brasil/datos/datos-2014.csv", encoding='ISO-8859-1', on_bad_lines='skip', sep=';')
datos_2014
# Out:
#       CÓDIGO ÓRGÃO SUPERIOR       NOME ÓRGÃO SUPERIOR  CÓDIGO ÓRGÃO  \
# 0                     63000  Advocacia-Geral da União         63000
# 1                     63000  Advocacia-Geral da União         63000
# 2                     63000  Advocacia-Geral da União         63000
# 3                     63000  Advocacia-Geral da União         63000
# 4                     63000  Advocacia-Geral da União         63000
# ...                     ...                       ...           ...
# 4548                  20000  Presidência da República         20101
# 4549                  20000  Presidência da República         20101
# 4550                  20000  Presidência da República         20101
# 4551                  20000  Presidência da República         20101
# 4552                  20000  Presidência da República         20101
#
#                                              NOME ÓRGÃO  \
# 0     Advocacia-Geral da União - Unidades com víncul...
# ...

# %%
datos_2015 = pd.read_csv("/Users/Charlie/Desktop/hackio/Proyecto2-EDA-Ingresos-Publicos-Brasil/datos/datos-2015.csv", encoding='ISO-8859-1', on_bad_lines='skip', sep=';')
datos_2015
# Out:
#       CÓDIGO ÓRGÃO SUPERIOR       NOME ÓRGÃO SUPERIOR  CÓDIGO ÓRGÃO  \
# 0                     63000  Advocacia-Geral da União         63000
# 1                     63000  Advocacia-Geral da União         63000
# 2                     63000  Advocacia-Geral da União         63000
# 3                     63000  Advocacia-Geral da União         63000
# 4                     63000  Advocacia-Geral da União         63000
# ...                     ...                       ...           ...
# 4518                  20000  Presidência da República         20101
# 4519                  20000  Presidência da República         20116
# 4520                  20000  Presidência da República         20101
# 4521                  20000  Presidência da República         20101
# 4522                  20000  Presidência da República         20101
#
#                                              NOME ÓRGÃO  \
# 0     Advocacia-Geral da União - Unidades com víncul...
# ...

# %%
datos_2016 = pd.read_csv("/Users/Charlie/Desktop/hackio/Proyecto2-EDA-Ingresos-Publicos-Brasil/datos/datos-2016.csv", encoding='ISO-8859-1', on_bad_lines='skip', sep=';')
datos_2016
# Out:
#         CÓDIGO ÓRGÃO SUPERIOR       NOME ÓRGÃO SUPERIOR  CÓDIGO ÓRGÃO  \
# 0                       63000  Advocacia-Geral da União         63000
# 1                       63000  Advocacia-Geral da União         63000
# 2                       63000  Advocacia-Geral da União         63000
# 3                       63000  Advocacia-Geral da União         63000
# 4                       63000  Advocacia-Geral da União         63000
# ...                       ...                       ...           ...
# 194528                  20000  Presidência da República         69000
# 194529                  20000  Presidência da República         69000
# 194530                  20000  Presidência da República         69000
# 194531                  20000  Presidência da República         69000
# 194532                  20000  Presidência da República         69000
#
#                                                NOME ÓRGÃO  \
# 0       Advocacia-Geral da União - Unidades com víncul...
# ...

# %%
datos_2017 = pd.read_csv("/Users/Charlie/Desktop/hackio/Proyecto2-EDA-Ingresos-Publicos-Brasil/datos/datos-2017.csv", encoding='ISO-8859-1', on_bad_lines='skip', sep=';')
datos_2017
# Out:
#         CÓDIGO ÓRGÃO SUPERIOR       NOME ÓRGÃO SUPERIOR  CÓDIGO ÓRGÃO  \
# 0                       63000  Advocacia-Geral da União         63000
# 1                       63000  Advocacia-Geral da União         63000
# 2                       63000  Advocacia-Geral da União         63000
# 3                       63000  Advocacia-Geral da União         63000
# 4                       63000  Advocacia-Geral da União         63000
# ...                       ...                       ...           ...
# 190474                  20000  Presidência da República         24208
# 190475                  20000  Presidência da República         24208
# 190476                  20000  Presidência da República         24208
# 190477                  20000  Presidência da República         24208
# 190478                  20000  Presidência da República         24208
#
#                                                NOME ÓRGÃO  \
# 0       Advocacia-Geral da União - Unidades com víncul...
# ...

# %%
datos_2018 = pd.read_csv("/Users/Charlie/Desktop/hackio/Proyecto2-EDA-Ingresos-Publicos-Brasil/datos/datos-2018.csv", encoding='ISO-8859-1', on_bad_lines='skip', sep=';')
datos_2018
# Out:
#         CÓDIGO ÓRGÃO SUPERIOR       NOME ÓRGÃO SUPERIOR  CÓDIGO ÓRGÃO  \
# 0                       63000  Advocacia-Geral da União         63000
# 1                       63000  Advocacia-Geral da União         63000
# 2                       63000  Advocacia-Geral da União         63000
# 3                       63000  Advocacia-Geral da União         63000
# 4                       63000  Advocacia-Geral da União         63000
# ...                       ...                       ...           ...
# 173939                  20000  Presidência da República         24208
# 173940                  20000  Presidência da República         24208
# 173941                  20000  Presidência da República         24208
# 173942                  20000  Presidência da República         24208
# 173943                  20000  Presidência da República         24208
#
#                                                NOME ÓRGÃO  \
# 0       Advocacia-Geral da União - Unidades com víncul...
# ...

# %%
datos_2019 = pd.read_csv("/Users/Charlie/Desktop/hackio/Proyecto2-EDA-Ingresos-Publicos-Brasil/datos/datos-2019.csv", encoding='ISO-8859-1', on_bad_lines='skip', sep=';')
datos_2019
# Out:
#         CÓDIGO ÓRGÃO SUPERIOR       NOME ÓRGÃO SUPERIOR  CÓDIGO ÓRGÃO  \
# 0                       63000  Advocacia-Geral da União         63000
# 1                       63000  Advocacia-Geral da União         63000
# 2                       63000  Advocacia-Geral da União         63000
# 3                       63000  Advocacia-Geral da União         63000
# 4                       63000  Advocacia-Geral da União         63000
# ...                       ...                       ...           ...
# 176823                  20000  Presidência da República         24208
# 176824                  20000  Presidência da República         24208
# 176825                  20000  Presidência da República         24208
# 176826                  20000  Presidência da República         24208
# 176827                  20000  Presidência da República         24208
#
#                                                NOME ÓRGÃO  \
# 0       Advocacia-Geral da União - Unidades com víncul...
# ...

# %%
datos_2020 = pd.read_csv("/Users/Charlie/Desktop/hackio/Proyecto2-EDA-Ingresos-Publicos-Brasil/datos/datos-2020.csv", encoding='ISO-8859-1', on_bad_lines='skip', sep=';')
datos_2020
# Out:
#         CÓDIGO ÓRGÃO SUPERIOR       NOME ÓRGÃO SUPERIOR  CÓDIGO ÓRGÃO  \
# 0                       63000  Advocacia-Geral da União         63000
# 1                       63000  Advocacia-Geral da União         63000
# 2                       63000  Advocacia-Geral da União         63000
# 3                       63000  Advocacia-Geral da União         63000
# 4                       63000  Advocacia-Geral da União         63000
# ...                       ...                       ...           ...
# 142343                  20000  Presidência da República         24208
# 142344                  20000  Presidência da República         24208
# 142345                  20000  Presidência da República         24208
# 142346                  20000  Presidência da República         24208
# 142347                  20000  Presidência da República         24208
#
#                                                NOME ÓRGÃO  \
# 0       Advocacia-Geral da União - Unidades com víncul...
# ...

# %%
datos_2021 = pd.read_csv("/Users/Charlie/Desktop/hackio/Proyecto2-EDA-Ingresos-Publicos-Brasil/datos/datos-2021.csv", encoding='ISO-8859-1', on_bad_lines='skip', sep=';')
datos_2021
# Out:
#         CÓDIGO ÓRGÃO SUPERIOR                            NOME ÓRGÃO SUPERIOR  \
# 0                       63000                       Advocacia-Geral da União
# 1                       63000                       Advocacia-Geral da União
# 2                       37000                   Controladoria-Geral da União
# 3                       22000  Ministério da Agricultura, Pecuária e Abastec
# 4                       22000  Ministério da Agricultura, Pecuária e Abastec
# ...                       ...                                            ...
# 134588                  20000                       Presidência da República
# 134589                  20000                       Presidência da República
# 134590                  20000                       Presidência da República
# 134591                  20000                       Presidência da República
# 134592                  20000                       Presidência da República
#
# ...

# %%
df_brasil = pd.concat([datos_2013, datos_2014, datos_2015, datos_2016, datos_2017, datos_2018, datos_2019, datos_2020, datos_2021])
df_brasil
# Out:
#         CÓDIGO ÓRGÃO SUPERIOR       NOME ÓRGÃO SUPERIOR  CÓDIGO ÓRGÃO  \
# 0                       63000  Advocacia-Geral da União         63000
# 1                       63000  Advocacia-Geral da União         63000
# 2                       63000  Advocacia-Geral da União         63000
# 3                       63000  Advocacia-Geral da União         63000
# 4                       63000  Advocacia-Geral da União         63000
# ...                       ...                       ...           ...
# 134588                  20000  Presidência da República         24208
# 134589                  20000  Presidência da República         24208
# 134590                  20000  Presidência da República         24208
# 134591                  20000  Presidência da República         24208
# 134592                  20000  Presidência da República         24208
#
#                                                NOME ÓRGÃO  \
# 0       Advocacia-Geral da União - Unidades com víncul...
# ...

# %%
df_brasil.columns
# Out:
# Index(['CÓDIGO ÓRGÃO SUPERIOR', 'NOME ÓRGÃO SUPERIOR', 'CÓDIGO ÓRGÃO',
#        'NOME ÓRGÃO', 'CÓDIGO UNIDADE GESTORA', 'NOME UNIDADE GESTORA',
#        'CATEGORIA ECONÔMICA', 'ORIGEM RECEITA', 'ESPÉCIE RECEITA',
#        'DETALHAMENTO', 'VALOR PREVISTO ATUALIZADO', 'VALOR LANÇADO',
#        'VALOR REALIZADO', 'PERCENTUAL REALIZADO', 'DATA LANÇAMENTO',
#        'ANO EXERCÍCIO'],
#       dtype='object')

# %%
df_brasil.rename(columns = {"CÓDIGO ÓRGÃO SUPERIOR":"CODIGO ORGANO SUPERIOR"}, inplace = True)

# %%
dict_columnas = {
    'NOME ÓRGÃO SUPERIOR': 'NOMBRE ÓRGANO SUPERIOR',
    'CÓDIGO ÓRGÃO': 'CÓDIGO ÓRGANO',
    'NOME ÓRGÃO': 'NOMBRE ÓRGANO',
    'CÓDIGO UNIDADE GESTORA': 'CÓDIGO UNIDAD GESTORA',
    'NOME UNIDADE GESTORA': 'NOMBRE UNIDAD GESTORA',
    'CATEGORIA ECONÔMICA': 'CATEGORÍA ECONÓMICA',
    'ORIGEM RECEITA': 'ORIGEN INGRESO',
    'ESPÉCIE RECEITA': 'ESPECIE INGRESO',
    'DETALHAMENTO': 'DETALLE',
    'VALOR PREVISTO ATUALIZADO': 'VALOR PREVISTO ACTUALIZADO',
    'VALOR LANÇADO': 'VALOR LANZADO',
    'VALOR REALIZADO': 'VALOR REALIZADO',
    'PERCENTUAL REALIZADO': 'PORCENTAJE REALIZADO',
    'DATA LANÇAMENTO': 'FECHA LANZAMIENTO',
    'ANO EXERCÍCIO': 'AÑO EJERCICIO'}

# %%
df_brasil.rename(columns = dict_columnas, inplace= True)
df_brasil
# Out:
#         CODIGO ORGANO SUPERIOR    NOMBRE ÓRGANO SUPERIOR  CÓDIGO ÓRGANO  \
# 0                        63000  Advocacia-Geral da União          63000
# 1                        63000  Advocacia-Geral da União          63000
# 2                        63000  Advocacia-Geral da União          63000
# 3                        63000  Advocacia-Geral da União          63000
# 4                        63000  Advocacia-Geral da União          63000
# ...                        ...                       ...            ...
# 134588                   20000  Presidência da República          24208
# 134589                   20000  Presidência da República          24208
# 134590                   20000  Presidência da República          24208
# 134591                   20000  Presidência da República          24208
# 134592                   20000  Presidência da República          24208
#
#                                             NOMBRE ÓRGANO  \
# ...

# %%
df_brasil.columns
# Out:
# Index(['CODIGO ORGANO SUPERIOR', 'NOMBRE ÓRGANO SUPERIOR', 'CÓDIGO ÓRGANO',
#        'NOMBRE ÓRGANO', 'CÓDIGO UNIDAD GESTORA', 'NOMBRE UNIDAD GESTORA',
#        'CATEGORÍA ECONÓMICA', 'ORIGEN INGRESO', 'ESPECIE INGRESO', 'DETALLE',
#        'VALOR PREVISTO ACTUALIZADO', 'VALOR LANZADO', 'VALOR REALIZADO',
#        'PORCENTAJE REALIZADO', 'FECHA LANZAMIENTO', 'AÑO EJERCICIO'],
#       dtype='object')

# %%
df_brasil.head()
# Out:
#    CODIGO ORGANO SUPERIOR    NOMBRE ÓRGANO SUPERIOR  CÓDIGO ÓRGANO  \
# 0                   63000  Advocacia-Geral da União          63000
# 1                   63000  Advocacia-Geral da União          63000
# 2                   63000  Advocacia-Geral da União          63000
# 3                   63000  Advocacia-Geral da União          63000
# 4                   63000  Advocacia-Geral da União          63000
#
#                                        NOMBRE ÓRGANO  CÓDIGO UNIDAD GESTORA  \
# 0  Advocacia-Geral da União - Unidades com víncul...                 110060
# 1  Advocacia-Geral da União - Unidades com víncul...                 110060
# 2  Advocacia-Geral da União - Unidades com víncul...                 110060
# 3  Advocacia-Geral da União - Unidades com víncul...                 110060
# 4  Advocacia-Geral da União - Unidades com víncul...                 110060
#
#                            NOMBRE UNIDAD GESTORA CATEGORÍA ECONÓMICA  \
# ...
